# %% [markdown]
# <a href="https://colab.research.google.com/github/jrdeborja/thesis-supp.-data/blob/main/descriptors_fingerprints_calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Calculation and generation of molecular descriptors (Mordred) and fingerprints (MACCS key using RDKit)**
#
# - authored by Joshua R. de Borja

# %% [markdown]
# # **Installs and Imports**

# %%
! pip install 'mordred[full]'
! pip install rdkit
# Out:
# Collecting mordred[full]
#   Downloading mordred-1.2.0.tar.gz (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six==1.* in /usr/local/lib/python3.10/dist-packages (from mordred[full]) (1.16.0)
# Requirement already satisfied: numpy==1.* in /usr/local/lib/python3.10/dist-packages (from mordred[full]) (1.23.5)
# Collecting networkx==2.* (from mordred[full])
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mordred[full]) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mordred[full]) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mordred[full]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mordred[full]) (2023.3.post1)
# Building wheels for collected packages: mordred
#   Building wheel for mordred (setup.py) ... done
#   Created wheel for mordred: filename=mordred-1.2.0-py3-none-any.whl size=176721 sha256=e68ae4b3cfeb4b77221ab30496c3e2cfbd86f0638255fda8587c4569227f1399
#   Stored in directory: /root/.cache/pip/wheels/a7/4f/b8/d4c6591f6ac944aaced7865b349477695f662388ad958743c7
# Successfully built mordred
# Installing collected packages: networkx, mordred
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed mordred-1.2.0 networkx-2.8.8
# Collecting rdkit
#   Downloading rdkit-2023.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 38.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.3

# %%
import pandas as pd
import numpy as np

from mordred import Calculator, descriptors

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import MACCSkeys
from rdkit.Chem import Descriptors
from rdkit.ML.Descriptors import MoleculeDescriptors

# %% [markdown]
# # **Dataset**
# - dataset for 1D, 2D and 3D molecular descriptor generation
# - and MACCS keys generation

# %%
train_test_dataset = pd.read_csv('https://raw.githubusercontent.com/jrdeborja/Thesis-code-repository/main/training_dataset_screened.csv')
rock1_dataset = pd.read_csv('https://raw.githubusercontent.com/jrdeborja/Thesis-code-repository/main/rock1_screened.csv')

# %%
df = pd.concat([train_test_dataset, rock1_dataset])

# %% [markdown]
# # **Mordred descriptors**

# %%
# Define a function to calculate all Mordred descriptors

def AllMordredDescriptors(data):
    calc = Calculator(descriptors, ignore_3D=False)
    mols = [Chem.MolFromSmiles(smi) for smi in data]
    df = calc.pandas(mols)
    return df

# %%
df_descriptors = AllMordredDescriptors(df['Smiles'])
# Out:
#   4%|▍         | 137/3463 [00:57<18:53,  2.93it/s]
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  16%|█▌        | 538/3463 [08:01<51:03:58, 62.85s/it]
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 3463/3463 [41:05<00:00,  1.40it/s]

# %%
df_descriptors
# Out:
#             ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0     36.871660  25.961217      1      0  60.964843  2.539247  4.958653
# 1     36.423773  25.622051      1      0  59.589557  2.539218  4.956426
# 2     34.900170  24.311455      1      0  57.883519  2.530083  4.940969
# 3     35.676226  25.257507      1      0  58.685792  2.539222  4.958165
# 4     38.285874  26.245294      1      0  63.880561  2.539229  4.963236
# ...         ...        ...    ...    ...        ...       ...       ...
# 3458  22.005839  16.402493      0      0  36.903668  2.488989  4.977978
# 3459  25.622253  19.095691      0      1  43.511354  2.396265  4.769294
# 3460  28.410240  20.775155      0      1  47.527962  2.414949  4.787615
# 3461  27.593743  20.293268      0      1  46.663461  2.402144  4.774809
# 3462  23.041115  19.095049      0      1  37.950494  2.450592  4.877047
#
#          SpAD_A   SpMAD_A   LogEE_A  ...      SRW10      TSRW10          MW  \
# 0     60.964843  1.325323  4.778552  ...  10.851374  100.226083  637.214362
# 1     59.589557  1.295425  4.764855  ...  10.804523   98.372666  639.193627
# 2     57.883519  1.315535  4.723315  ...  10.761704   96.170286  607.223784
# 3     58.685792  1.304129  4.745318  ...  10.807321   97.331362  625.214362
# 4     63.880561  1.330845  4.815478  ...  10.873300  100.678434  665.245663
# ...         ...       ...       ...  ...        ...         ...         ...
# 3458  36.903668  1.317988  4.271395  ...  10.351789   63.651485  374.163043
# 3459  43.511354  1.318526  4.419778  ...  10.276877   82.041476  447.227040
# 3460  47.527962  1.320221  4.521408  ...  10.452505   88.225903  502.178710
# 3461  46.663461  1.333242  4.493924  ...  10.408466   87.046354  488.163060
# 3462  37.950494  1.265016  4.313895  ...  10.197090   78.944070  410.211804
#
#            AMW WPath WPol  Zagreb1  Zagreb2   mZagreb1   mZagreb2
# 0     8.066005  8351   79    254.0    306.0  12.888889   9.888889
# 1     8.301216  8437   78    248.0    295.0  14.388889   9.944444
# 2     7.784920  7598   75    238.0    284.0  13.277778   9.527778
# 3     8.015569  7899   78    244.0    292.0  14.138889   9.722222
# 4     7.826420  9437   83    262.0    314.0  13.388889  10.388889
# ...        ...   ...  ...      ...      ...        ...        ...
# 3458  7.483261  2171   48    150.0    179.0   8.611111   6.166667
# 3459  7.213339  3817   49    170.0    197.0   9.861111   7.361111
# 3460  8.099657  4861   55    192.0    226.0  10.333333   7.888889
# 3461  8.273950  4480   53    186.0    219.0   9.472222   7.722222
# 3462  7.196698  2547   45    152.0    176.0  10.611111   6.666667
#
# [3463 rows x 1826 columns]

# %% [markdown]
# # **RDKit MACCS keys**

# %%
# Define a function to calculate the MACCS keys

def MACCSFingerprints(data):
    maccs_fpts = []
    for i in data:
        mol = Chem.MolFromSmiles(i)
        fpts =  AllChem.GetMACCSKeysFingerprint(mol)
        mfpts = np.array(fpts)
        maccs_fpts.append(mfpts)
    return np.array(maccs_fpts)

# %%
df_maccs = pd.DataFrame(MACCSFingerprints(df['Smiles']))

# %%
# Reset all of the indexes

df.reset_index(drop=True, inplace=True)
df_descriptors.reset_index(drop=True, inplace=True)
df_maccs.reset_index(drop=True, inplace=True)

# %%
final_df_for_ml = pd.concat([df, df_descriptors, df_maccs], axis=1)

# %%
final_df_for_ml
# Out:
#       Unnamed: 0 Molecule.ChEMBL.ID  \
# 0           2102       CHEMBL210297
# 1           3101      CHEMBL2296935
# 2           4101       CHEMBL376688
# 3           5101       CHEMBL374567
# 4           6101       CHEMBL411712
# ...          ...                ...
# 3458         966      CHEMBL4763198
# 3459         967      CHEMBL3949136
# 3460         968      CHEMBL3961538
# 3461         969      CHEMBL3902471
# 3462         970      CHEMBL4107027
#
#                                                  Smiles Standard.Relation  \
# 0     O=C(O)c1ccc2c(c1)nc(-c1ccc(OCc3cc(N4CCCC4=O)cc...               '='
# 1     CC(=O)NC(=O)c1ccc(-c2ccc(Cl)cc2)c(COc2ccc(-c3n...               '='
# 2     CN(C)C(=O)c1ccc(-c2ccc(Cl)cc2)c(COc2ccc(-c3nc4...               '='
# 3     CC(=O)N(C)c1ccc(-c2ccc(Cl)cc2)c(COc2ccc(-c3nc4...               '='
# 4     O=C(O)c1ccc2c(c1)nc(-c1ccc(OCc3cc(C(=O)N4CCCCC...               '='
# ...                                                 ...               ...
# 3458  COc1cccc([C@@H](C)NC(=O)c2ccc3c(c2)C(C)Oc2cncc...               '='
# 3459  COc1cc(C(=O)NCc2cccc(C(=O)NC3CCN(C)CC3)c2)ccc1...               '='
# 3460  COc1cc(C(=O)NCc2cccc(C(=O)Nc3nc4c(s3)CN(C)CC4)...               '='
# 3461  COc1cc(C(=O)NCc2cccc(C(=O)Nc3nc4c(s3)CNCC4)c2)...               '='
# 3462  Cc1n[nH]cc1-c1cc(OCCN(C)C)c(C(=O)N[C@H](C)c2cc...               '='
#
#       Standard.Value Document.ChEMBL.ID         Molar     pIC50  \
# 0        83368118.46      CHEMBL3045038  8.336812e-02  1.079000
# 1        71449632.61      CHEMBL3045038  7.144963e-02  1.146000
# 2        66680676.92      CHEMBL3045038  6.668068e-02  1.176000
# 3        62517269.28      CHEMBL3045038  6.251727e-02  1.204000
# 4        55590425.73      CHEMBL3045038  5.559043e-02  1.255000
# ...              ...                ...           ...       ...
# 3458            0.49      CHEMBL4665758  4.900000e-10  9.309804
# 3459            0.43      CHEMBL3886981  4.300000e-10  9.366532
# 3460            0.39      CHEMBL3886981  3.900000e-10  9.408935
# 3461            0.26      CHEMBL3886981  2.600000e-10  9.585027
# 3462            0.20      CHEMBL3886981  2.000000e-10  9.698970
#
#      Bioactivity.Class        ABC  ...  157  158  159 160 161 162 163 164 165  \
# 0             inactive  36.871660  ...    1    1    1   0   1   1   1   1   1
# 1             inactive  36.423773  ...    1    1    1   1   1   1   1   1   1
# 2             inactive  34.900170  ...    1    1    1   1   1   1   1   1   1
# 3             inactive  35.676226  ...    1    1    1   1   1   1   1   1   1
# 4             inactive  38.285874  ...    1    1    1   0   1   1   1   1   1
# ...                ...        ...  ...  ...  ...  ...  ..  ..  ..  ..  ..  ..
# 3458            active  22.005839  ...    1    1    1   1   1   1   1   1   1
# 3459            active  25.622253  ...    1    1    1   1   1   1   1   1   1
# 3460            active  28.410240  ...    1    1    1   1   1   1   1   1   1
# 3461            active  27.593743  ...    1    1    1   1   1   1   1   1   1
# 3462            active  23.041115  ...    1    1    1   1   1   1   1   1   1
#
#      166
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 3458   0
# 3459   0
# 3460   0
# 3461   0
# 3462   0
#
# [3463 rows x 2002 columns]

# %% [markdown]
# # **Google Drive export**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
final_df_for_ml.to_csv('/content/drive/MyDrive/Mordred & RDKit files/final_dataset_for_ml.csv', index=False)
